# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import json
with open('/Users/tijes/.secret/yelp_api.json') as f:
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
# import the YelpAPI Class
from yelpapi import YelpAPI
# Create an instance with your key
yelp_api = YelpAPI(login['api-key'], timeout_s=5.0)
yelp_api

# %%
# use our yelp_api variable's search_query method to perform our API call
search_results = yelp_api.search_query(location='Colorado Springs, CO,80920',
                                       term='Ice cream')
print(type(search_results))
search_results.keys()
# Out:
# <class 'dict'>
# dict_keys(['businesses', 'total', 'region'])

# %%
search_results['total']
# Out:
# 168

# %%
biz = pd.DataFrame(search_results['businesses'])
biz
# Out:
#                         id                                              alias  \
# 0   kjRDuI8ZtWMR03UC-zsbYQ  josh-and-johns-naturally-homemade-ice-cream-co...
# 1   pY8KJsUocWbNveoFPQezIg                          i-cool-colorado-springs-3
# 2   WXWFlPIJaHPcVu1ljerDfw  josh-and-johns-homemade-ice-creams-colorado-sp...
# 3   oq8PXu_79htFjY_lOGld1Q            blue-mountain-creamery-colorado-springs
# 4   1oZ3B_rfvGsVxAF8Pgoa2A                           rizutos-colorado-springs
# 5   m3ARlDm29LvyH2qX-hdNOw               lulus-frozen-yogurt-colorado-springs
# 6   oBmqTrz9EF-Wp1bUUgArNA                       haagen-dazs-colorado-springs
# 7   J3siRWKIOcIj8NpEjmQZ1Q             cold-stone-creamery-colorado-springs-3
# 8   tRQ3HJ_ovn9UpWajwqyovA                          javalato-colorado-springs
# 9   t812NbvLJjNGzCkNjNWzAw   decadent-coffee-and-dessert-bar-colorado-springs
# 10  hlS2E0C8BEL4vMK6sVgc6g    3-14-sweet-and-savory-pi-bar-colorado-springs-2
# ...

# %%
# Save the businesses as a records-oriented JSON file. (df.to_json(orient='records'))
biz_js = biz.to_json(orient='records')

# %%
# add offset to our original api call
search_results = yelp_api.search_query(location='Colorado Springs, CO,80920',
                                       term='Ice cream', offset = 20)

# %%
biz20 = pd.DataFrame(search_results['businesses'])
biz20
# Out:
#                         id                                              alias  \
# 0   xzHBG67LaHmuro-ysF8Ctw       rocky-mtn-chocolate-factory-colorado-springs
# 1   r-zTzvqnfZc3VPHJe6lvPQ  rocky-mountain-chocolate-factory-colorado-spri...
# 2   PO8baQOTZd0eLCIlY45XCw                   special-grounds-colorado-springs
# 3   qLLTFNJbFP--jiulPxpQmw  freddys-frozen-custard-and-steakburgers-colora...
# 4   JEN-gT5SpdWvGXOtw0c4Kg                           ritas-colorado-springs-3
# 5   tuikiJkzxrZwkpPJtfYqiQ                           culvers-colorado-springs
# 6   -sdwBBrPv3apzW9PSZWUAg                       fiiz-drinks-colorado-springs
# 7   Jv_JTtoylXXJ5g7wXPDvnw            menchies-frozen-yogurt-colorado-springs
# 8   5DCpeUDa4YTdAHHEUE7wkw                   teapioca-lounge-colorado-springs
# 9   ROLoBYQd2p6wny6wjsDZvg  freddys-frozen-custard-and-steakburgers-colora...
# 10  oX16bH475hpAmmqWF7qbOQ              the-cupcake-doctor-colorado-springs-2
# ...

# %%
## Concatenate the results into one data frame 
businesses = pd.concat([biz, biz20],
                      ignore_index=True)
display(businesses)
# Out:
#                         id                                              alias  \
# 0   kjRDuI8ZtWMR03UC-zsbYQ  josh-and-johns-naturally-homemade-ice-cream-co...
# 1   pY8KJsUocWbNveoFPQezIg                          i-cool-colorado-springs-3
# 2   WXWFlPIJaHPcVu1ljerDfw  josh-and-johns-homemade-ice-creams-colorado-sp...
# 3   oq8PXu_79htFjY_lOGld1Q            blue-mountain-creamery-colorado-springs
# 4   1oZ3B_rfvGsVxAF8Pgoa2A                           rizutos-colorado-springs
# 5   m3ARlDm29LvyH2qX-hdNOw               lulus-frozen-yogurt-colorado-springs
# 6   oBmqTrz9EF-Wp1bUUgArNA                       haagen-dazs-colorado-springs
# 7   J3siRWKIOcIj8NpEjmQZ1Q             cold-stone-creamery-colorado-springs-3
# 8   tRQ3HJ_ovn9UpWajwqyovA                          javalato-colorado-springs
# 9   t812NbvLJjNGzCkNjNWzAw   decadent-coffee-and-dessert-bar-colorado-springs
# 10  hlS2E0C8BEL4vMK6sVgc6g    3-14-sweet-and-savory-pi-bar-colorado-springs-2
# ...
